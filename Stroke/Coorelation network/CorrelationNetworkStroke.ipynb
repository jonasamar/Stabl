# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd 
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from scipy.interpolate import splprep, splev
from sklearn.cluster import KMeans
from scipy.spatial import ConvexHull
from pathlib import Path

# %config InlineBackend.figure_formats=['retina']

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import VarianceThreshold

from stabl.stabl import Stabl, plot_stabl_path
from stabl.preprocessing import remove_low_info_samples, LowInfoFilter
from stabl.visualization import boxplot_features

# %% [markdown]
# # Data

# %%
cell_pops = ['Bcells','CCR2nncMC', 'CCR2pcMC', 'CD41hiCD61hiPLT', 'CD4Tcm',
                        'CD4Tem', 'CD4Tnaive', 'CD4Trm', 'CD56brightCP26nNKcells',
                        'CD56dimCP26pNKcells', 'CD61pCD41pPLT', 'CD62LnAgedNeutrophils',
                        'CD62LpImmatureNeutrophils', 'CD8Tcm', 'CD8Tem', 'CD8Tnaive',
                        'CD8Trm', 'gdTcells', 'intMC', 'mDC', 'MDSC', 'NKT', 'pDC',
                        'Th1mem', 'Th1naive', 'Tregmem', 'Tregnaive']
times = ['P1', 'P2', 'P3']

# %%
dict_tot = {}
for time in times:
    y = pd.read_csv(Path('./Data', time, cellpop, 'y.csv'), index_col=0)
    y.index = [str(idx) + '_' + time for idx in y.index]
    y.columns = ['outcome']
    dict_tot['y' + time] = y
    
    dict_tot[time] = pd.DataFrame()
    for cellpop in cell_pops:
        X = pd.read_csv(Path('./Data', time, cellpop, 'X.csv'), index_col=0)
        X.columns = [cellpop + '_' + el for el in X.columns]
        X.index = [str(idx) + '_' + time for idx in X.index]
        dict_tot[time] = pd.concat([dict_tot[time] ,X], axis=1)

# %%
# P1_unstim = pd.read_csv('../Data_POCK/Immuno/P1_Unstim&Freq.csv', index_col=0)
# P1_unstim.columns = [el[1]+'_'+el[-1] for el in P1_unstim.columns.str.split('_')]
# P1 = P1_unstim.copy()
# P1.index = [idx + '_P1' for idx in P1.index]
# labels_P1 = pd.read_csv('../Data_POCK/Immuno/labels_P1.csv', index_col=0)
# # labels_P1.index = [idx + '_P1' for idx in labels_P1.index]

# P2_unstim = pd.read_csv('../Data_POCK/Immuno/P2_Unstim&Freq.csv', index_col=0)
# P2_unstim.columns = [el[1]+'_'+el[-1] for el in P2_unstim.columns.str.split('_')]
# P2 = P2_unstim.copy()
# P2.index = [idx + '_P2' for idx in P2.index]
# labels_P2 = pd.read_csv('../Data_POCK/Immuno/labels_P2.csv', index_col=0)
# # labels_P2.index = [idx + '_P2' for idx in labels_P2.index]

# P3_unstim = pd.read_csv('../Data_POCK/Immuno/P3_Unstim&Freq.csv', index_col=0)
# P3_unstim.columns = [el[1]+'_'+el[-1] for el in P3_unstim.columns.str.split('_')]
# P3 = P3_unstim.copy()
# P3.index = [idx + '_P3' for idx in P3.index]
# labels_P3 = pd.read_csv('../Data_POCK/Immuno/labels_P3.csv', index_col=0)
# # labels_P3.index = [idx + '_P3' for idx in labels_P3.index]

# D90_unstim = pd.read_csv('../Data_POCK/Immuno/D90_Unstim&Freq.csv', index_col=0)
# D90_unstim.columns = [el[1]+'_'+el[-1] for el in D90_unstim.columns.str.split('_')]
# D90 = D90_unstim.copy()
# D90.index = [idx + '_D90' for idx in D90.index]
# labels_D90 = pd.read_csv('../Data_POCK/Immuno/labels_D90.csv', index_col=0)
# # labels_D90.index = [idx + '_D90' for idx in labels_D90.index]

# %%
df_tot = pd.concat([dict_tot[time] for time in times], axis='rows')

# %% [markdown]
# # ANOVA

# %%
X_P1 = dict_tot['P1'].join(dict_tot['yP1'])
X_P1['TimePoint'] = 0
X_P2 = dict_tot['P2'].join(dict_tot['yP2'])
X_P2['TimePoint'] = 1
X_P3 = dict_tot['P3'].join(dict_tot['yP3'])
X_P3['TimePoint'] = 2

# %%
#df_anova = pd.concat([X_P1, X_P2, X_P3],axis='rows').dropna(subset=['outcome']).reset_index(drop=True)
#df_anova.fillna(df_anova.median(), inplace=True)

df_anova = pd.concat([X_P1, X_P2, X_P3],axis='rows').dropna(subset=['outcome']).reset_index(drop=True)

# %%
df_anova['outcome'] = df_anova.outcome.astype(int)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
pvalues_anova = pd.DataFrame(index = df_anova.columns)
for feature in df_anova.columns:
    # Ordinary Least Squares (OLS) model
    model = ols(f'{feature} ~ C(outcome)*C(TimePoint)', data=df_anova).fit()
    table = sm.stats.anova_lm(model,typ=1)
    pvalues_anova.loc[feature,'pvalue_anova']=table.loc['C(outcome)', 'PR(>F)']

# %%
pvalues_anova = pvalues_anova.fillna(1)

# %% [markdown]
# # t-SNE

# %%
df_corr = df_tot.corr()

# %%
tsne = TSNE(learning_rate='auto', random_state=4).fit(df_tot.fillna(df_tot.median()).T)
df_tsne = pd.DataFrame(data=tsne.embedding_, index = df_tot.columns, columns = ['coor1', 'coor2'])

# %%
clusterer = KMeans(n_clusters=10, n_init=100, random_state=42, init='k-means++')
cluster_labels = clusterer.fit_predict(df_tsne[['coor1', 'coor2']])
cen_x, cen_y = clusterer.cluster_centers_.T
df_tsne['cluster'] = cluster_labels

# %%
df_tsne = pd.concat([df_tsne, pvalues_anova], axis='columns')

# %% [markdown]
# # Correlation Plot

# %%
#df_tsne.to_csv('./df_tsne.csv')

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

colors = [(1, 0, 0), (.7, .4, 0), (0, 0, 1)]  # R -> G -> B
colors = [(0,(0, 0, 1)),(.35,(227/256, 163/256, 103/256)),(.65,(227/256, 163/256, 103/256)), (1,(1, 0, 0))]
n_bins = [3, 6, 10, 100]  # Discretizes the interpolation into bins
cmap_name = 'custom_cmp'

cmap = LinearSegmentedColormap.from_list(cmap_name, colors, N=256,gamma=1)

# %%
from adjustText import adjust_text
from matplotlib import colors

CORR_THRESH = .7
TIMESTAMP = 'P3'
# sizes_source = 'pvalue_'+TIMESTAMP
sizes_source = 'pvalue_anova'
#colors_source = 'effect_dir_'+TIMESTAMP

SIZES = []
for value in df_tsne[sizes_source].astype(float):
    if value > 0.05:
        SIZES.append(5)
    else:
        SIZES.append(2*(-np.log10(value)*6)**2)

def transform_to_color(i):
    if i < np.inf:
        return 'C' + str(int(i))
    else:
        return 'white'

COLORS = [transform_to_color(i) for i in df_tsne.cluster]

fig, ax = plt.subplots(figsize=(10, 10))

# --DRAWING CLUSTERS--

for i in np.unique(cluster_labels):
    points = df_tsne[df_tsne.cluster == i][['coor1', 'coor2']].values
    # get convex hull
    hull = ConvexHull(points)
    # get x and y coordinates
    # repeat last point to close the polygon
    x_hull = np.append(points[hull.vertices,0],
                       points[hull.vertices,0][0])
    y_hull = np.append(points[hull.vertices,1],
                       points[hull.vertices,1][0])
    
    tck, _ = splprep([x_hull, y_hull], s=0, per = True)
    xx, yy = splev(np.linspace(0, 1, 100), tck, der = 0)
    
    # plot shape
    plt.fill(xx, yy, alpha=.1, color='C'+str(int(i)), label=f'Cluster {int(i)}')

# --DRAWING POINTS--
scatter = plt.scatter(df_tsne.coor1,
                     df_tsne.coor2, 
                     s=SIZES, 
                     marker='o', 
                     c=COLORS,
                     norm=colors.CenteredNorm(),
                     edgecolors=None,
                     cmap=cmap,
                     alpha=.7
                    )

ax.axis("off")

fig.colorbar(scatter,
             anchor=(0, 0),
             ax=ax, 
             shrink=.2, 
             label='Effect direction', 
             aspect=8, 
             use_gridspec=True,
             location='right'
            )

def funct(s):
    to_ret=np.zeros(len(s))
    for idx, el in enumerate(s):
        if el==5:
            to_ret[idx] = 1
        else:
            to_ret[idx] = np.exp(np.log(10)*(-((el/2)**(1/2))/6))
    return to_ret

kw = dict(prop="sizes", num=[1, 0.05, 0.01, 0.001], color='gray',
          func=funct)

# kw = dict(prop="sizes", num=[0, .1, .2], color='gray', fmt="{x:.2f}",
#            func=lambda s: np.sqrt(s)/75 - 0.01)£

ax.legend(*scatter.legend_elements(**kw),title="ANOVA pvalue",labelspacing=2, loc='lower right', frameon=False)
plt.legend()

for i in df_tot.columns:
    for j in df_tot.columns:
        if df_corr.loc[i,j]>=CORR_THRESH and df_corr.loc[i,j] < 1:
            sub_df = df_tsne.loc[[i, j]]
            ax.plot(sub_df.coor1, sub_df.coor2, linewidth=.2,color='gray', alpha=.05)
            
annot=[]        
for i, txt in enumerate(df_tsne.index):
    if df_tsne.iloc[i][sizes_source] <= 0.0005:
        annot.append(ax.annotate(txt, (df_tsne.iloc[i].coor1, df_tsne.iloc[i].coor2), fontsize=12))
        
adjust_text(annot)

#plt.savefig('./Correlation networks/Correlation network - ANOVA/correlation networks.pdf', dpi=200)
# Out:
# /var/folders/v_/wlr8vlpn1tzgb7_j_7kncp4w0000gn/T/ipykernel_13045/3065821263.py:15: RuntimeWarning: divide by zero encountered in log10
#   SIZES.append(2*(-np.log10(value)*6)**2)
# /var/folders/v_/wlr8vlpn1tzgb7_j_7kncp4w0000gn/T/ipykernel_13045/3065821263.py:47: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   scatter = plt.scatter(df_tsne.coor1,
# /Users/jonasamar/Stabl/.venv/lib/python3.9/site-packages/numpy/core/function_base.py:157: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# 500

# %%
from adjustText import adjust_text
from matplotlib import colors

CORR_THRESH = .7
TIMESTAMP = 'P1'
# sizes_source = 'pvalue_'+TIMESTAMP
sizes_source = 'pvalue_anova'
#colors_source = 'effect_dir_'+TIMESTAMP

SIZES = []
for value in df_tsne[sizes_source].astype(float):
    if value > 0.05:
        SIZES.append(5)
    else:
        SIZES.append(2*(-np.log10(value)*6)**2)

        
def transform_to_color(i):
    if i < np.inf:
        return 'C' + str(int(i))
    else:
        return 'white'

COLORS = [transform_to_color(i) for i in df_tsne.cluster]

fig, ax = plt.subplots(figsize=(10, 10))

# --DRAWING CLUSTERS--

for i in np.unique(cluster_labels):
    points = df_tsne[df_tsne.cluster == i][['coor1', 'coor2']].values
    # get convex hull
    hull = ConvexHull(points)
    # get x and y coordinates
    # repeat last point to close the polygon
    x_hull = np.append(points[hull.vertices,0],
                       points[hull.vertices,0][0])
    y_hull = np.append(points[hull.vertices,1],
                       points[hull.vertices,1][0])
    
    tck, _ = splprep([x_hull, y_hull], s=0, per = True)
    xx, yy = splev(np.linspace(0, 1, 100), tck, der = 0)
    
    # plot shape
    plt.fill(xx, yy, alpha=.1, color='C'+str(i), label=f'Cluster {i}')

# --DRAWING POINTS--
scatter = plt.scatter(df_tsne.coor1,
                     df_tsne.coor2, 
                     s=SIZES, 
                     marker='o', 
                     c=COLORS,
                     norm=colors.CenteredNorm(),
                     edgecolors=None,
                     cmap=cmap,
                     alpha=.7
                    )

ax.axis("off")
plt.legend()
# fig.colorbar(scatter,
#              anchor=(0, 0),
#              ax=ax, 
#              shrink=.2, 
#              label='Effect direction', 
#              aspect=8, 
#              use_gridspec=True,
#              location='right'
#             )

def funct(s):
    to_ret=np.zeros(len(s))
    for idx, el in enumerate(s):
        if el==5:
            to_ret[idx] = 1
        else:
            to_ret[idx] = np.exp(np.log(10)*(-((el/2)**(1/2))/6))
    return to_ret

#kw = dict(prop="sizes", num=[1, 0.05, 0.01, 0.001], color='gray',
#          func=funct)

kw = dict(prop="sizes", num=[0, .1, .2], color='gray', fmt="{x:.2f}",
            func=lambda s: s)

ax.legend(*scatter.legend_elements(**kw),title="ANOVA pvalue",labelspacing=2, loc='lower right', frameon=False)

for i in df_tot.columns:
    for j in df_tot.columns:
        if df_corr.loc[i,j]>=CORR_THRESH and df_corr.loc[i,j] < 1:
            sub_df = df_tsne.loc[[i, j]]
            ax.plot(sub_df.coor1, sub_df.coor2, linewidth=.2,color='gray', alpha=.05)
            
annot=[]        
for i, txt in enumerate(df_tsne.index):
    if df_tsne.iloc[i][sizes_source] <= 0.0005:
        annot.append(ax.annotate(txt, (df_tsne.iloc[i].coor1, df_tsne.iloc[i].coor2), fontsize=12))
        
adjust_text(annot)
plt.show()
#plt.savefig('./Correlation networks/Correlation network - ANOVA/correlation networks.pdf', dpi=200)
# Out:
#   Cell In[127], line 81
#     func=funct)
#     ^
# IndentationError: unexpected indent
